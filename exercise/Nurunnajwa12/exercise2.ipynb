# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/foo.txt

drive.flush_and_unmount()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-a2d1194e6216> in <cell line: 1>()
# ----> 1 with open('/content/drive/My Drive/foo.txt', 'w') as f:
#       2   f.write('Hello Google Drive!')
#       3 get_ipython().system('cat /content/drive/My\\ Drive/foo.txt')
#       4
#       5 drive.flush_and_unmount()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/foo.txt'

# %%
with open('/content/drive/My Drive/myname.txt', 'w') as f:
  f.write('Hello Nurun!')
# !cat /content/drive/My\ Drive/foo.txt

drive.flush_and_unmount()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-ef1e9547ca5f> in <cell line: 1>()
# ----> 1 with open('/content/drive/My Drive/myname.txt', 'w') as f:
#       2   f.write('Hello Nurun!')
#       3 get_ipython().system('cat /content/drive/My\\ Drive/foo.txt')
#       4
#       5 drive.flush_and_unmount()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/myname.txt'

# %%
import pandas as pd

path = "/content/drive/MyDrive/Discount_Coupon.csv"

df = pd.read_csv(path)

df #displays dataframe
# Out:
#     Month      Product_Category Coupon_Code  Discount_pct
# 0     Jan               Apparel      SALE10            10
# 1     Feb               Apparel      SALE20            20
# 2     Mar               Apparel      SALE30            30
# 3     Jan              Nest-USA      ELEC10            10
# 4     Feb              Nest-USA      ELEC20            20
# ..    ...                   ...         ...           ...
# 199   Nov  Notebooks & Journals        NJ20            20
# 200   Dec  Notebooks & Journals        NJ30            30
# 201   Oct               Android       AND10            10
# 202   Nov               Android       AND20            20
# 203   Dec               Android       AND30            30
#
# [204 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             204 non-null    object
#  1   Product_Category  204 non-null    object
#  2   Coupon_Code       204 non-null    object
#  3   Discount_pct      204 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 6.5+ KB

# %%
df.describe()
# Out:
#        Discount_pct
# count    204.000000
# mean      20.000000
# std        8.185052
# min       10.000000
# 25%       10.000000
# 50%       20.000000
# 75%       30.000000
# max       30.000000

# %%
df.hist(bins=50, figsize=(15,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-86b371b29256> in <cell line: 2>()
#       1 df.hist(bins=50, figsize=(15,10))
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd

path = "/content/drive/MyDrive/Marketing_Spend.csv"

df = pd.read_csv(path)

df #displays dataframe
# Out:
#            Date  Offline_Spend  Online_Spend
# 0      1/1/2019           4500       2424.50
# 1      1/2/2019           4500       3480.36
# 2      1/3/2019           4500       1576.38
# 3      1/4/2019           4500       2928.55
# 4      1/5/2019           4500       4055.30
# ..          ...            ...           ...
# 360  12/27/2019           4000       3396.87
# 361  12/28/2019           4000       3246.84
# 362  12/29/2019           4000       2546.58
# 363  12/30/2019           4000        674.31
# 364  12/31/2019           4000       2058.75
#
# [365 rows x 3 columns]

# %%
df.hist(bins=50, figsize=(15,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-86b371b29256> in <cell line: 2>()
#       1 df.hist(bins=50, figsize=(15,10))
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined
